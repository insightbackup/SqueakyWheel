# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.datasets import fetch_20newsgroups
from sklearn.decomposition import NMF, LatentDirichletAllocation

n_docs = 10
def display_topics(model, feature_names, no_top_words,documents,tfidf):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic {0}:".format(topic_idx))
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))
        foo = nmf.transform(tfidf)
        top_doc_indices = np.argsort( foo[:,topic_idx] )[::-1][0:n_docs]
        print(top_doc_indices)
        for doc_index in top_doc_indices:
            print(topic_tweets[doc_index])

#dataset = fetch_20newsgroups(shuffle=True, random_state=1, remove=('headers', 'footers', 'quotes'))
#documents = dataset.data
all_tweets = pd.read_csv('train_tweets.csv')
i=18
sources = all_tweets['source'].unique().tolist()
source= sources[i]
print(source)
topic_tweets = all_tweets[all_tweets['source']==source]['text'].tolist()
documents = topic_tweets

no_features = 1000

# NMF is able to use tf-idf
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')
tfidf = tfidf_vectorizer.fit_transform(documents)
tfidf_feature_names = tfidf_vectorizer.get_feature_names()

# LDA can only use raw term counts for LDA because it is a probabilistic graphical model
#tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,  stop_words='english')
#tf = tf_vectorizer.fit_transform(documents)
#tf_feature_names = tf_vectorizer.get_feature_names()

no_topics = 10

# Run NMF
nmf = NMF(n_components=no_topics, random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd').fit(tfidf)
n_top_documents = 5
n_top_words = 5
# get list of feature names
feature_names = tfidf_vectorizer.get_feature_names()
#for topic_id, topic in enumerate(nmf.components_):
        #word_list = []
        #for i in topic.argsort()[:-n_top_words - 1:-1]:
        #    word_list.append(feature_names[i])
            

            # check that the review contains one of the topic words
            #if any(word in df['reviewText'].iloc[doc_index].lower() for word in topic_words):

# Run LDA
#lda = LatentDirichletAllocation(n_topics=no_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(tf)

no_top_words = 5
display_topics(nmf, tfidf_feature_names, no_top_words,documents,tfidf)
#display_topics(lda, tf_feature_names, no_top_words)
# Out:
# @@NikeSupport
# Topic 0:
# run club nike app facebook
# [66 31 69 11 40 30 23 50  1 33]
# hi, i just accidentally deleted a run on my nike run club app         is there any way to get it back?
# why can't i connect with facebook friends on nike run club?
# hey guys  could you please add nigeria lagos to the running community on the nike run club app  thanks
# if my run app doesn't track a run in my training plan by accident (two days in a row btw) then is there a way for me to pull in the run data already collected to count toward my training plan? i only see the option to add a run and enter new data manually
# app is not saving my indoor runs  i complete the run, then after taking a picture it is asking me are you sure you want to discard the run?
# como puedo enterarme de entrenamientos y rutinas de nike run club en medellin?
# hey  i'm having trouble connecting my facebook account to the nike  running club app
# i did my 3 mile run and the app crashed and i didn'tget credit
# hola buena tarde quisiera saber si me pueden ayudar con mi cuenta nike  run club
# hey    what's the correct way to start a run on my apple watch 3? very frustrated because hitting the start button doesn't start it  when i hit start, it looks like it accepts the press, but nothing happens  i have to hit it like 30 times before the run starts  help!
# Topic 1:
# fans listen return power weeks
# [25 49 60  9 24 20 21 22 23 72]
# listen to the fans!
#
#
# listen to the fans!
#
# return the power k!
#
#
# stripe the stadium! listen to the fans! return the power k! and beat msu!
#
#
# great win cats!
#
# return the power k!
#
#
# return the power k!
#
# get rid of the crooked k!
#
#
# meus treinos n o est o sendo computados nos desvios
# bonjour j'aimerai conna tre la m thode pour figurer dans les classements du genre nrc nike plus 'just doit (les 3 communaut s   la une dans l' app
# cordialement
#
# i think  should release some shoes dedicated to  and have the profits go to local foundation that helps with drug addiction
# hey  i'm having trouble connecting my facebook account to the nike  running club app
# hey guys you have a super awesome app however it's not updating my challenges after i complete a run   can you help?
# Topic 2:
# la en que el puedo
# [70 12 39 21 47 41  5 58 30 36]
#  c mo puedo regresar a la voz femenina anterior en el  no me ha agradado nada la nueva voz, es m s lenta al dar los tiempos y m s robotizada, no me siento c modo  ?
# ayuda con la app ntc, no he podido agregar a una amiga ni me llega su invitaci n y la env o hace 8 d as
# no se reflejan en mi plan de entrenamiento de nike run club la distancia que corr  hoy, inclusive la cumpl  en dos diferentes carreras
# bonjour j'aimerai conna tre la m thode pour figurer dans les classements du genre nrc nike plus 'just doit (les 3 communaut s   la une dans l' app
# cordialement
#
# no para de borrarme kms creo que la deinstalare antes de octubre
# necesito que me ayuden con el entrenamiento, en un mes tengo examen
# no puedo generar un nuevo plan me indica que ocurri  un error de conexi n ya hace una semana tanto con wifi como con datos libres
# ayer hice 6km y no los veo reflejados en mi cuenta
# como puedo enterarme de entrenamientos y rutinas de nike run club en medellin?
# hola  mis actividades no se sincronizan desde hace dos semanas    me pueden ayudar por favor?? gracias!!
# Topic 3:
# hey new nike like donating
# [53 42  3 63 16  6 23 69  2 72]
# hey  this is   logo
# hey  when will i get the new indian football jersey????
# hey    i love this nike   but how is possible i m loosing the heel in less than 50km ??
# hey          approaching the end of life on my second pair of  feel like donating a lifelong  user a new pair?
# hey  how do i get in the nrc beta test for wear os?
# "nrc on wearos is now available in beta  join the beta program"
# hey team,
# off late the nrc app has had a glitch where suddenly it stops counting the distance and keeps the clock going, rendering the information incorrect
# hey  i'm having trouble connecting my facebook account to the nike  running club app
# hey guys  could you please add nigeria lagos to the running community on the nike run club app  thanks
# hey  i bought this acg level 3 jacket over 20 years ago! (1997 i think)  it survived each canadian winter since (up mountains  snowstorms  hail ) and has survived it all  i m so sad that today i found the first thing to break from this, my favourite jacket  any help?
# hey guys you have a super awesome app however it's not updating my challenges after i complete a run   can you help?
# Topic 4:
# nrc mail trocar app distance
# [ 8 29 16  6 62 21 68 48 26 14]
#   poss vel trocar o e mail registrado no app nrc?
# ol  como fa o para trocar o e mail da minha conta nrc ? o e mail foi extinguido e eu n o consigo utilizar o app junto com meu rel gio
# hey  how do i get in the nrc beta test for wear os?
# "nrc on wearos is now available in beta  join the beta program"
# hey team,
# off late the nrc app has had a glitch where suddenly it stops counting the distance and keeps the clock going, rendering the information incorrect
# my nrc tracks my runs but doesn't mark as completed on my coach plan  (
# bonjour j'aimerai conna tre la m thode pour figurer dans les classements du genre nrc nike plus 'just doit (les 3 communaut s   la une dans l' app
# cordialement
#
# hi  i did mistake while using nrc this morning, the apps was hang and sadly i took discard  is there any chance for me to get my running record? thanks a lot
# dear  your app has given me headaches last week    app had wrong milage, crashed while running then stopped working
# i have uninstalled the app more than 5 times  amp  not opening at all i am training for  marathon with no plan at all
# check dm for details
# so, i started using your app 3 weeks ago  the maps never worked  the coach stopped giving instructions completely after the second workout, and just gives time, pace and distance  today, it stopped giving distance  how can i fix this?
# my runs are not getting synced for couple of weeks now  is there a problem with your app on android
# Topic 5:
# need couldn fix don team
# [ 0 19 38 57 34 35  6  5 33 32]
# c mon man  two wears?!?! you gotta be kidding me  what y all making these jordan 1 s with? i need answers! smh
# we need to talk   aaa couldn t save me
# why  shirts shrink after the first wash and  don t? y all need to fix that
# hi   i need assistance please pm me  the chat team is not able to assist me with an order i have that was cancelled by you guys
# like after every release,   please fix your android app  it is literally broken and i couldn't even load checkout boxes for any of the prestos  not to mention the snkrs pass didn't even load yesterday
# it didn t say if i won or lost the nike presto deal on snkrs app,
#
# thanks anyway, don t even know why i even try lol
# hey team,
# off late the nrc app has had a glitch where suddenly it stops counting the distance and keeps the clock going, rendering the information incorrect
# no puedo generar un nuevo plan me indica que ocurri  un error de conexi n ya hace una semana tanto con wifi como con datos libres
# hey    what's the correct way to start a run on my apple watch 3? very frustrated because hitting the start button doesn't start it  when i hit start, it looks like it accepts the press, but nothing happens  i have to hit it like 30 times before the run starts  help!
# hey  first time, long time  i bought these a month ago from  and i ve put some mileage on them, but i ve never had a shoe do this before  not pleased!
# Topic 6:
# today help think ago bought
# [ 2 37 13 32 26 72 33 22 61 68]
# hey  i bought this acg level 3 jacket over 20 years ago! (1997 i think)  it survived each canadian winter since (up mountains  snowstorms  hail ) and has survived it all  i m so sad that today i found the first thing to break from this, my favourite jacket  any help?
# by mistake, i discarded today's run  can you help me retrieve it?
# super confused about my run on your four week intro course today  i had to do 400m sprints i think but i passed 400m and the coach didn't say anything?
# hey  first time, long time  i bought these a month ago from  and i ve put some mileage on them, but i ve never had a shoe do this before  not pleased!
# so, i started using your app 3 weeks ago  the maps never worked  the coach stopped giving instructions completely after the second workout, and just gives time, pace and distance  today, it stopped giving distance  how can i fix this?
# hey guys you have a super awesome app however it's not updating my challenges after i complete a run   can you help?
# hey    what's the correct way to start a run on my apple watch 3? very frustrated because hitting the start button doesn't start it  when i hit start, it looks like it accepts the press, but nothing happens  i have to hit it like 30 times before the run starts  help!
# i think  should release some shoes dedicated to  and have the profits go to local foundation that helps with drug addiction
# i am having an issue in my nike  running application  it says "connection server error"  i tried uninstalling the app, updating the app few times   but still getting the error  not logging my kms properly even with gps and internet connection on   plz help
# hi  i did mistake while using nrc this morning, the apps was hang and sadly i took discard  is there any chance for me to get my running record? thanks a lot
# Topic 7:
# power return cats like looks
# [65  9 24 55 60 49 33 54 63 34]
# we aren t houston! looks like an h! embarrassing!
#
# return the power k! go cats!
#
#
# great win cats!
#
# return the power k!
#
#
# return the power k!
#
# get rid of the crooked k!
#
#
# yes! make it permanent!
#
# get rid of the embarrassing crooked k! it looks like an h!
#
#
# stripe the stadium! listen to the fans! return the power k! and beat msu!
#
#
# listen to the fans!
#
# return the power k!
#
#
# hey    what's the correct way to start a run on my apple watch 3? very frustrated because hitting the start button doesn't start it  when i hit start, it looks like it accepts the press, but nothing happens  i have to hit it like 30 times before the run starts  help!
# so i blocked nike, to the extent this  service allowed me to  probably took 30 minutes, seemed like seconds
#
#
#
#
#
#
#
#
# hey          approaching the end of life on my second pair of  feel like donating a lifelong  user a new pair?
# like after every release,   please fix your android app  it is literally broken and i couldn't even load checkout boxes for any of the prestos  not to mention the snkrs pass didn't even load yesterday
# Topic 8:
# shoes marathon release think weeks
# [59 22 34 48 13  2 72 24 21 23]
# if only i got the marathon shoes or arrived early for the race
# i think  should release some shoes dedicated to  and have the profits go to local foundation that helps with drug addiction
# like after every release,   please fix your android app  it is literally broken and i couldn't even load checkout boxes for any of the prestos  not to mention the snkrs pass didn't even load yesterday
# dear  your app has given me headaches last week    app had wrong milage, crashed while running then stopped working
# i have uninstalled the app more than 5 times  amp  not opening at all i am training for  marathon with no plan at all
# check dm for details
# super confused about my run on your four week intro course today  i had to do 400m sprints i think but i passed 400m and the coach didn't say anything?
# hey  i bought this acg level 3 jacket over 20 years ago! (1997 i think)  it survived each canadian winter since (up mountains  snowstorms  hail ) and has survived it all  i m so sad that today i found the first thing to break from this, my favourite jacket  any help?
# hey guys you have a super awesome app however it's not updating my challenges after i complete a run   can you help?
# return the power k!
#
# get rid of the crooked k!
#
#
# bonjour j'aimerai conna tre la m thode pour figurer dans les classements du genre nrc nike plus 'just doit (les 3 communaut s   la une dans l' app
# cordialement
#
# hey  i'm having trouble connecting my facebook account to the nike  running club app
# Topic 9:
# air nike just hey service
# [27 45  3 71 21 10 54 66 35 26]
# for nike to retro the air ship   sign the petition!  via
# hey  the air bubble in my air max s just popped  what the heck do i do
# hey    i love this nike   but how is possible i m loosing the heel in less than 50km ??
# just ordered me some fresh  and donating the outdated nikes
# bonjour j'aimerai conna tre la m thode pour figurer dans les classements du genre nrc nike plus 'just doit (les 3 communaut s   la une dans l' app
# cordialement
#
# i am very displeased and disappointed with nike's customers service  i sent back my aqua kyries twice because of faulty sneakers that nearly caught on fire, shoe laces burnt off while playing bball and still no justice!!
# so i blocked nike, to the extent this  service allowed me to  probably took 30 minutes, seemed like seconds
#
#
#
#
#
#
#
#
# hi, i just accidentally deleted a run on my nike run club app         is there any way to get it back?
# it didn t say if i won or lost the nike presto deal on snkrs app,
#
# thanks anyway, don t even know why i even try lol
# so, i started using your app 3 weeks ago  the maps never worked  the coach stopped giving instructions completely after the second workout, and just gives time, pace and distance  today, it stopped giving distance  how can i fix this?

# %%
from textblob import TextBlob
sentiment = []
for tweet in train_tweets['text']:
    
     # create TextBlob object of passed tweet text 
    analysis = TextBlob(tweet)
    tweetiment = analysis.sentiment.polarity
        # set sentiment 
    #if analysis.sentiment.polarity > 0: 
    #    tweetiment =  'positive'
    #elif analysis.sentiment.polarity == 0: 
    #    tweetiment = 'neutral'
    #else: 
    #    tweetiment = 'negative'
    sentiment.append(tweetiment)
train_tweets['sentiment'] = sentiment
